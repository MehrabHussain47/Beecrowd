# %% [markdown]
# <a href="https://colab.research.google.com/github/MehrabHussain47/Beecrowd/blob/master/_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
print("Hello World!")
# Out:
# Hello World!
