# %% [markdown]
# <a href="https://colab.research.google.com/github/MehrabHussain47/Beecrowd/blob/master/_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
radius = float(input())
area = 3.14159 * radius * radius
print(f"A={area:.4f}")
# Out:
#  100.64
# A=31819.3103
