# %% [markdown]
# <a href="https://colab.research.google.com/github/MehrabHussain47/Beecrowd/blob/master/_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
x = int(input())
y = int(input())
result = x + y
print("X = " + str(result))
# Out:
# 10
# 9
# X = 19
